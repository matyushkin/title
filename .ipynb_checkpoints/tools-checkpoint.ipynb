# %% [markdown]
# # Additional tools unnecassary for daily work
#
# This notebook contains various solutions that were used for intermediate work with datasets. They can be useful for future product expansion, but not for current work.

# %%
from os import listdir
import pandas as pd
import dask.dataframe as dd
from tqdm.notebook import tqdm
tqdm.pandas()

# %%
df_meta = pd.read_feather(f'../IT_TEXTS/DATASETS/META/it_articles_ru.feather')
df_meta = df_meta.rename(columns={'index':'url'})
df_meta
# Out:
#                                                       url  \
# 0       https://tproger.ru/articles/7-prakticheskih-za...
# 1       https://tproger.ru/quiz/test-chto-mozhet-jeta-...
# 2       https://tproger.ru/articles/kak-najti-dejstvit...
# 3       https://tproger.ru/articles/blackbox-skanery-v...
# 4       https://tproger.ru/articles/instrumenty-upravl...
# ...                                                   ...
# 261908                    https://habr.com/ru/post/16357/
# 261909                   https://habr.com/ru/post/180551/
# 261910  https://habr.com/ru/company/microsoft/blog/180...
# 261911                   https://habr.com/ru/post/180399/
# 261912     https://habr.com/ru/company/zfort/blog/180153/
#
#                                                     title  \
# 0       7 практических заданий с собеседования на пози...
# 1             Тест: что реально, а что создала нейросеть?
# 2       Как найти действительно хороший курс по разраб...
# 3       Blackbox-сканеры в процессе оценки безопасност...
# 4       Инструменты управления командой разработки на ...
# ...                                                   ...
# 261908               VoIP в России — Сервис FlashPhone.ru
# 261909  Про рейтинги: Ху из ху на рынке digital-аналит...
# 261910  Стартап-история месяца конкурса Microsoft BizS...
# 261911                            Не localhost'ом единым?
# 261912  Дайджест интересных новостей и материалов из м...
#
#                                                   summary  views_num  \
# 0       Для начинающего разработчика очень важно не то...       8642
# 1       Сегодня нейронные сети используются в сельском...       4967
# 2       Сразу хочется пошутить и предложить разработат...       1291
# 3       Профиль задач quality engineer (QE) достаточно...        233
# 4       В КРОК геораспределенная структура офисов разр...        589
# ...                                                   ...        ...
# 261908  В начале осени я писал, про то что, Flex будет...        304
# 261909  Среди компаний веб-разработки принято мериться...       5100
# 261910  Теперь когда все уже вполне вернулись в строй ...       3700
# 261911  По мотивам комментария:\nИнтересно, у какого п...      17800
# 261912  Предлагаем вашему вниманию очередную подборку ...      30000
#
#                  post_time parse_time  likes_num  favs_num  comments_num  \
# 0      2021-03-01 09:05:11 2021-04-19         13        10            10
# 1      2021-02-26 19:39:50 2021-04-19          2         1             0
# 2      2021-02-26 17:29:00 2021-04-19          1         4             1
# 3      2021-02-26 15:16:46 2021-04-19          0         1             0
# 4      2021-02-25 18:56:54 2021-04-19          3         3             0
# ...                    ...        ...        ...       ...           ...
# 261908 2007-11-18 18:14:00 2021-04-23          4         5            22
# 261909 2013-05-22 14:03:00 2021-04-23         -4        10             6
# 261910 2013-05-21 11:03:00 2021-04-23          0         3             3
# 261911 2013-05-21 10:04:00 2021-04-23          6        10            45
# 261912 2013-05-18 20:07:00 2021-04-23         26       141             9
#
#          source  fulltext_saved
# 0       tproger               1
# 1       tproger               1
# 2       tproger               1
# 3       tproger               1
# 4       tproger               1
# ...         ...             ...
# 261908     habr               0
# 261909     habr               0
# 261910     habr               0
# 261911     habr               0
# 261912     habr               0
#
# [261913 rows x 11 columns]

# %% [markdown]
# ## Compile many tiny fulltext files into a single feather file:

# %%
def read_func(path, filename):
    with open(path + filename, 'r') as reader:
        return reader.read()


def many_to_one(name):
    path = f'../IT_TEXTS/DATASETS/{name}/'
    df = pd.DataFrame({'filename':listdir(path)})
    df['fulltext'] = df.filename.progress_apply(lambda filename: read_func(path, filename))
    df.to_feather(f'../IT_TEXTS/DATASETS/FULLTEXTS/{name}.feather',
                  compression='zstd')

# %% [markdown]
# ## Check that url `fulltext` exists

# %%
df_meta = df_meta.drop(columns='filename')

# %%
def check_fulltext(url):
    if url in fulltexts_url_list:
        return 1
    else:
        return 0

def check()
    path = '../IT_TEXTS/DATASETS/FULLTEXTS/'
    df_filenames = listdir(path)
    df = pd.concat([pd.read_feather(f'{path}{name}') for name in df_filenames ])
    df = df.reset_index().drop(columns='index')
    fulltexts_url_list = df.filename.to_list()
    df_meta['fulltext_saved'] = df_meta.url.progress_apply(check_fulltext)
    df_meta.to_feather(f'../IT_TEXTS/DATASETS/META/it_articles_ru.feather',
                   compression='zstd')
